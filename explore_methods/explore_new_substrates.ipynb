# %%
import pandas as pd

new_smiles = pd.read_csv("../data_to_sciathon_new/process_new_smiles.csv")
glove_enzymes = pd.read_csv("../results/coding_protein/glove.csv")

# %%
glove_enzymes
# Out:
#         p_0       p_1       p_2       p_3       p_4       p_5       p_6  \
# 0 -0.007266 -0.026588  0.048395  0.044534  0.085637 -0.016740  0.018524
# 1 -0.017544 -0.021512  0.057123  0.041498  0.081256 -0.024149  0.000726
# 2 -0.012698 -0.030297  0.055319  0.045124  0.084733 -0.027858  0.006042
# 3 -0.029904 -0.022681  0.049940  0.051508  0.076308 -0.028898  0.006561
# 4 -0.032042 -0.024744  0.044248  0.053850  0.083117 -0.022254  0.009487
# 5 -0.037474 -0.023646  0.040535  0.055116  0.076459 -0.034510  0.004027
# 6  0.018417 -0.041343  0.061911  0.027315  0.086779 -0.022281  0.022120
# 7 -0.011046 -0.026422  0.056549  0.050298  0.077516 -0.028806  0.005903
# 8 -0.021058 -0.027823  0.045872  0.048413  0.079141 -0.032802  0.012433
#
#         p_7       p_8       p_9  ...     p_503     p_504     p_505     p_506  \
# 0 -0.003965 -0.008943 -0.013071  ...  0.021947 -0.034287  0.067886 -0.103010
# 1 -0.004150 -0.009576 -0.014253  ...  0.036235 -0.037369  0.075485 -0.094815
# ...

# %%
#concat
matrix_data = []

for index in new_smiles.index:
    for index2 in glove_enzymes.index:
        row = []
        for column in glove_enzymes.columns:
            if "p_" in column:
                row.append(glove_enzymes[column][index2])
        for column in new_smiles.columns:
            if "p_" in column:
                row.append(new_smiles[column][index])
        
        matrix_data.append(row)

header = ["p_{}".format(i) for i in range(len(matrix_data[0]))]
df_data = pd.DataFrame(matrix_data, columns=header)

# %%
from joblib import load

model_trained = load("../results/training_model_exploration/model_optim_with_all_examples.joblib")
# Out:
# /home/dmedina/miniconda3/envs/data_driven_library/lib/python3.9/site-packages/sklearn/base.py:299: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/dmedina/miniconda3/envs/data_driven_library/lib/python3.9/site-packages/sklearn/base.py:299: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.24.2 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
predictions = model_trained.predict(df_data)
predictions
# Out:
# /home/dmedina/miniconda3/envs/data_driven_library/lib/python3.9/site-packages/sklearn/base.py:413: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...
